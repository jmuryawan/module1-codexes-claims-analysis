# %% [markdown]
# <a href="https://colab.research.google.com/github/jmuryawan/module1-codexes-claims-analysis/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv', sep= '|')
# Out:
# <ipython-input-55-1732a64f4927>:1: DtypeWarning: Columns (168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://data.cms.gov/sites/default/files/2023-04/67157de9-d962-4af0-bf0e-3578b3afec58/inpatient.csv', sep= '|')

# %%
df
# Out:
#               BENE_ID          CLM_ID NCH_NEAR_LINE_REC_IDENT_CD  \
# 0     -10000010254618 -10000930037831                          V
# 1     -10000010254653 -10000930038030                          V
# 2     -10000010254653 -10000930038031                          V
# 3     -10000010254656 -10000930038162                          V
# 4     -10000010254656 -10000930038162                          V
# ...               ...             ...                        ...
# 58061 -10000010288008 -10000931485965                          V
# 58062 -10000010288008 -10000931485967                          V
# 58063 -10000010288008 -10000931485969                          V
# 58064 -10000010288008 -10000931485971                          V
# 58065 -10000010288010 -10000931486024                          V
#
#        NCH_CLM_TYPE_CD  CLM_FROM_DT  CLM_THRU_DT NCH_WKLY_PROC_DT  \
# 0                   60  25-Mar-2015  25-Mar-2015      27-Mar-2015
# ...

# %%
for a in df.columns:
  print(a)
# Out:
# BENE_ID
# CLM_ID
# NCH_NEAR_LINE_REC_IDENT_CD
# NCH_CLM_TYPE_CD
# CLM_FROM_DT
# CLM_THRU_DT
# NCH_WKLY_PROC_DT
# FI_CLM_PROC_DT
# CLAIM_QUERY_CODE
# PRVDR_NUM
# CLM_FAC_TYPE_CD
# CLM_SRVC_CLSFCTN_TYPE_CD
# CLM_FREQ_CD
# FI_NUM
# CLM_MDCR_NON_PMT_RSN_CD
# CLM_PMT_AMT
# NCH_PRMRY_PYR_CLM_PD_AMT
# NCH_PRMRY_PYR_CD
# FI_CLM_ACTN_CD
# PRVDR_STATE_CD
# ORG_NPI_NUM
# AT_PHYSN_UPIN
# AT_PHYSN_NPI
# OP_PHYSN_UPIN
# OP_PHYSN_NPI
# OT_PHYSN_UPIN
# OT_PHYSN_NPI
# CLM_MCO_PD_SW
# PTNT_DSCHRG_STUS_CD
# CLM_PPS_IND_CD
# CLM_TOT_CHRG_AMT
# CLM_ADMSN_DT
# CLM_IP_ADMSN_TYPE_CD
# CLM_SRC_IP_ADMSN_CD
# NCH_PTNT_STATUS_IND_CD
# CLM_PASS_THRU_PER_DIEM_AMT
# NCH_BENE_IP_DDCTBL_AMT
# NCH_BENE_PTA_COINSRNC_LBLTY_AM
# NCH_BENE_BLOOD_DDCTBL_LBLTY_AM
# NCH_PROFNL_CMPNT_CHRG_AMT
# NCH_IP_NCVRD_CHRG_AMT
# NCH_IP_TOT_DDCTN_AMT
# CLM_TOT_PPS_CPTL_AMT
# CLM_PPS_CPTL_FSP_AMT
# CLM_PPS_CPTL_OUTLIER_AMT
# CLM_PPS_CPTL_DSPRPRTNT_SHR_AMT
# CLM_PPS_CPTL_IME_AMT
# CLM_PPS_CPTL_EXCPTN_AMT
# CLM_PPS_OLD_CPTL_HLD_HRMLS_AMT
# ...

# %%
### frequencies ###

# %%
## 1. relates to Claim Diagnosis Related Group Code (or MS-DRG Code)
df ['CLM_DRG_CD'].value_counts()
# Out:
# CLM_DRG_CD
# 951.0    28831
# 950.0     1456
# 949.0     1332
# 922.0     1110
# 923.0     1015
#          ...
# 814.0        1
# 918.0        1
# 870.0        1
# 812.0        1
# 656.0        1
# Name: count, Length: 167, dtype: int64

# %%
## 2. relates to Healthcare Common Procedure Coding System (HCPCS) Code
df ['HCPCS_CD'].value_counts()
# Out:
# HCPCS_CD
# 99221    8298
# G0444    7990
# 96156    5080
# 99408    4196
# 99495    3867
#          ...
# S9361       1
# S9355       1
# S9374       1
# S9377       1
# G9829       1
# Name: count, Length: 106, dtype: int64

# %%
## 3. relates to Claim Diagnosis Code
df ['ICD_DGNS_CD1'].value_counts()
# Out:
# ICD_DGNS_CD1
# Z733      13031
# Z608       8227
# T7432X     3727
# Z604       3537
# Z940       2858
#           ...
# T8611         1
# E1141         1
# E11610        1
# I071          1
# M069          1
# Name: count, Length: 231, dtype: int64

# %%
## 4. relates to Claim Diagnosis E Code Present on Admission (POA) Indicator Code
df ['CLM_E_POA_IND_SW4'].value_counts()
# Out:
# CLM_E_POA_IND_SW4
#      58066
# Name: count, dtype: int64

# %%
## 5. relates to Claim Admitting Diagnosis Code
df ['ADMTG_DGNS_CD'].value_counts()
# Out:
# ADMTG_DGNS_CD
# Z7682      2881
# T50901A    2541
# Z951       1694
# Z95818     1058
# C3490       940
#            ...
# E849          1
# A4152         1
# O00109        1
# I200          1
# C9200         1
# Name: count, Length: 65, dtype: int64

# %%
## 6. relates to Claim Diagnosis Code Present on Admission (POA) Indicator Code
df ['CLM_POA_IND_SW19'].value_counts()
# Out:
# CLM_POA_IND_SW19
# Y    24714
# N     3036
# Name: count, dtype: int64

# %%
## 7. relates to Claim Diagnosis E Code
df ['ICD_DGNS_E_CD7'].value_counts()
# Out:
# ICD_DGNS_E_CD7
#      58066
# Name: count, dtype: int64

# %%
## 8. relates to Claim Procedure Code
df ['ICD_PRCDR_CD15'].value_counts()
# Out:
# ICD_PRCDR_CD15
# Z9981      800
# F08H5ZZ    496
# F13        176
# Z8616       24
# 0BP13DZ     14
# Name: count, dtype: int64

# %%
### missing data ###

# %%
## using .isnull to find null values in the whole file. 'True' = null values
df.isnull()
# Out:
#        BENE_ID  CLM_ID  NCH_NEAR_LINE_REC_IDENT_CD  NCH_CLM_TYPE_CD  \
# 0        False   False                       False            False
# 1        False   False                       False            False
# 2        False   False                       False            False
# 3        False   False                       False            False
# 4        False   False                       False            False
# ...        ...     ...                         ...              ...
# 58061    False   False                       False            False
# 58062    False   False                       False            False
# 58063    False   False                       False            False
# 58064    False   False                       False            False
# 58065    False   False                       False            False
#
#        CLM_FROM_DT  CLM_THRU_DT  NCH_WKLY_PROC_DT  FI_CLM_PROC_DT  \
# 0            False        False             False            True
# ...

# %%
## shows how many null values there are per column
missing = df.isnull().sum()
print(missing)
# Out:
# BENE_ID                            0
# CLM_ID                             0
# NCH_NEAR_LINE_REC_IDENT_CD         0
# NCH_CLM_TYPE_CD                    0
# CLM_FROM_DT                        0
#                                ...
# CLM_UNCOMPD_CARE_PMT_AMT       58066
# CLM_LINE_NUM                       0
# REV_CNTR                           0
# HCPCS_CD                           0
# REV_CNTR_DDCTBL_COINSRNC_CD     8298
# Length: 197, dtype: int64

# %%
## 1. there are 3262 null values in CLM_DRG_CD column
df ['CLM_DRG_CD'].isnull().sum()
# Out:
# 3262

# %%
## 2. there are 0 null value in HCPCS_CD column
df ['HCPCS_CD'].isnull().sum()
# Out:
# 0

# %%
## 3. there are 0 null values in ICD_DGNS_CD1 column
df ['ICD_DGNS_CD1'].isnull().sum()
# Out:
# 0

# %%
## 4. there are 0 null values in CLM_E_POA_IND_SW4 column
df ['CLM_E_POA_IND_SW4'].isnull().sum()
# Out:
# 0

# %%
## 5. there are 41938 null values in ADMTG_DGNS_CD column
df ['ADMTG_DGNS_CD'].isnull().sum()
# Out:
# 41938

# %%
## 6. there are 30316 null values in CLM_POA_IND_SW19 column
df ['CLM_POA_IND_SW19'].isnull().sum()
# Out:
# 30316

# %%
## 7. there are 0 null values in ICD_DGNS_E_CD7 column
df ['ICD_DGNS_E_CD7'].isnull().sum()
# Out:
# 0

# %%
## 8. there are 56556 null values in ICD_PRCDR_CD15 column
df ['ICD_PRCDR_CD15'].isnull().sum()
# Out:
# 56556

# %%
### handling missing data ###

# %%
## 1. replacing missing data with column average
df ['CLM_DRG_CD'].fillna(df ['CLM_DRG_CD'].mean)
# Out:
# 0                                                    551.0
# 1                                                    951.0
# 2                                                    923.0
# 3                                                    564.0
# 4                                                    564.0
#                                ...
# 58061    <bound method Series.mean of 0        551.0\n1...
# 58062    <bound method Series.mean of 0        551.0\n1...
# 58063    <bound method Series.mean of 0        551.0\n1...
# 58064    <bound method Series.mean of 0        551.0\n1...
# 58065                                                963.0
# Name: CLM_DRG_CD, Length: 58066, dtype: object

# %%
## 5. dropping missing data
df ['ADMTG_DGNS_CD'].dropna()
# Out:
# 1          Z3480
# 5          Z3480
# 6          Z3400
# 7           R569
# 23         R5081
#           ...
# 58060    T50901A
# 58061    T50901A
# 58062    T50901A
# 58063    T50901A
# 58064    T50901A
# Name: ADMTG_DGNS_CD, Length: 16128, dtype: object

# %%
## 6. replacing missing data with 'NULL'
df ['CLM_POA_IND_SW19'].fillna('NULL')
# Out:
# 0        NULL
# 1        NULL
# 2        NULL
# 3        NULL
# 4        NULL
#          ...
# 58061    NULL
# 58062    NULL
# 58063    NULL
# 58064    NULL
# 58065    NULL
# Name: CLM_POA_IND_SW19, Length: 58066, dtype: object

# %%
## 8. replacing missing data with 0
df['ICD_PRCDR_CD15'].fillna('0')
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 58061    0
# 58062    0
# 58063    0
# 58064    0
# 58065    0
# Name: ICD_PRCDR_CD15, Length: 58066, dtype: object

# %% [markdown]
# additional analysis
#
# *   the most common codes found were HCPCS, DRG, and ICD
# *   there is a lot of missing data
